# %% [markdown]
# Data cleaning for data related to enrollments of students in Canada
# Data taken from Statscan - Table: 37-10-0011-01 (formerly CANSIM 477-0029)

# %%
import pandas as pd

# %%
# read csv file
df = pd.read_csv("37100018.csv")
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_17348\3798948813.py:2: DtypeWarning: Columns (17) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("37100018.csv")

# %%
# Assuming you have a DataFrame named df
memory_in_bytes = df.memory_usage(deep=True).sum()
memory_in_mb = memory_in_bytes / (1024 ** 2)  # Convert bytes to MB

print(f"The DataFrame takes up {memory_in_mb:.2f} MB in memory.")
# Out:
# The DataFrame takes up 4905.61 MB in memory.

# %%
# 4.6 mln records
df.shape
# Out:
# (4645275, 21)

# %%
# clean data by deleting not usefull data
df_clean = df.drop(columns = ['DGUID', 'UOM', 'UOM_ID', 'TERMINATED', 'SCALAR_FACTOR', 'SCALAR_ID', 'VECTOR', 'COORDINATE', 'STATUS', 'SYMBOL', 'TERMINATED', 'DECIMALS'])

df_clean = df_clean[df_clean['Selected statistics'] == 'Number']
df_clean = df_clean.drop(columns = ['Selected statistics'])

# %%
# rename some data
df_clean = df_clean.replace(to_replace=r'^Total.*', value='Total', regex=True)

# rename columns
df_clean = df_clean.rename(columns = {'REF_DATE': 'Date', 'GEO': 'Location', 'Status of student in Canada': 'Status of student', 'VALUE': 'Value', 'International Standard Classification of Education (ISCED)': 'ISCED'})

# reconfigure date column
df_clean['Date'] = df_clean['Date'].str.split('/').str[0].astype(int)

# %%
# showcase how data looks like
df_clean
# Out:
#          Date     Location Institution type Registration status  \
# 0        1992       Canada            Total               Total
# 2        1992       Canada            Total               Total
# 4        1992       Canada            Total               Total
# 6        1992       Canada            Total               Total
# 8        1992       Canada            Total               Total
# ...       ...          ...              ...                 ...
# 4645265  2021  Territories          College   Part-time student
# 4645267  2021  Territories          College   Part-time student
# 4645269  2021  Territories          College   Part-time student
# 4645271  2021  Territories          College   Part-time student
# 4645273  2021  Territories          College   Part-time student
#
#                                                      ISCED  \
# 0                                                    Total
# 2                                                    Total
# 4                                                    Total
# 6                                                    Total
# 8                                                    Total
# ...                                                    ...
# 4645265  Not applicable, International Standard Classif...
# 4645267  Not applicable, International Standard Classif...
# 4645269  Not applicable, International Standard Classif...
# 4645271  Not applicable, International Standard Classif...
# 4645273  Not applicable, International Standard Classif...
#
#                                Field of study Gender  \
# 0                                       Total  Total
# 2                                       Total  Total
# 4                                       Total  Total
# 6                                       Total  Total
# 8                                       Total    Man
# ...                                       ...    ...
# 4645265  Personal improvement and leisure [0]  Woman
# 4645267                          Unclassified  Total
# 4645269                          Unclassified  Total
# 4645271                          Unclassified  Woman
# 4645273                          Unclassified  Woman
#
#                                  Status of student      Value
# 0                                            Total  1355451.0
# 2                                Canadian students  1190811.0
# 4                           International students    40620.0
# 6        Not reported, status of student in Canada   124023.0
# 8                                            Total   608616.0
# ...                                            ...        ...
# 4645265                          Canadian students        6.0
# 4645267                                      Total        6.0
# 4645269                          Canadian students        6.0
# 4645271                                      Total        6.0
# 4645273                          Canadian students        6.0
#
# [2720040 rows x 9 columns]

# %%
df_clean.columns
# Out:
# Index(['Date', 'Location', 'Institution type', 'Registration status', 'ISCED',
#        'Field of study', 'Gender', 'Status of student', 'Value'],
#       dtype='object')

# %%
# Delete row with "Canada" or "Total" in them because they duplicate calculations
df_filtered = df_clean[~df_clean.astype(str).apply(lambda x: x.str.contains('Total|Canada', case=False, na=False)).any(axis=1).values]

# %%
df_filtered
# Out:
#          Date                   Location Institution type Registration status  \
# 25736    1992  Newfoundland and Labrador       University   Full-time student
# 25745    1992  Newfoundland and Labrador       University   Full-time student
# 25747    1992  Newfoundland and Labrador       University   Full-time student
# 25750    1992  Newfoundland and Labrador       University   Full-time student
# 25752    1992  Newfoundland and Labrador       University   Full-time student
# ...       ...                        ...              ...                 ...
# 4645239  2021                Territories          College   Part-time student
# 4645242  2021                Territories          College   Part-time student
# 4645261  2021                Territories          College   Part-time student
# 4645265  2021                Territories          College   Part-time student
# 4645273  2021                Territories          College   Part-time student
#
#                                                      ISCED  \
# 25736                             Bachelor's or equivalent
# 25745                             Bachelor's or equivalent
# 25747                             Bachelor's or equivalent
# 25750                             Bachelor's or equivalent
# 25752                             Bachelor's or equivalent
# ...                                                    ...
# 4645239                           Bachelor's or equivalent
# 4645242                           Bachelor's or equivalent
# 4645261  Not applicable, International Standard Classif...
# 4645265  Not applicable, International Standard Classif...
# 4645273  Not applicable, International Standard Classif...
#
#                                Field of study          Gender  \
# 25736    Personal improvement and leisure [0]           Woman
# 25745                           Education [1]             Man
# 25747                           Education [1]             Man
# 25750                           Education [1]           Woman
# 25752                           Education [1]           Woman
# ...                                       ...             ...
# 4645239                           Other  [12]           Woman
# 4645242                           Other  [12]  Gender unknown
# 4645261  Personal improvement and leisure [0]             Man
# 4645265  Personal improvement and leisure [0]           Woman
# 4645273                          Unclassified           Woman
#
#               Status of student  Value
# 25736         Canadian students    NaN
# 25745         Canadian students  153.0
# 25747    International students    NaN
# 25750         Canadian students  543.0
# 25752    International students    NaN
# ...                         ...    ...
# 4645239       Canadian students    6.0
# 4645242       Canadian students    3.0
# 4645261       Canadian students    9.0
# 4645265       Canadian students    6.0
# 4645273       Canadian students    6.0
#
# [231102 rows x 9 columns]

# %%
# save clean data
df_filtered.to_csv('enrollments_data.csv', index = False)
